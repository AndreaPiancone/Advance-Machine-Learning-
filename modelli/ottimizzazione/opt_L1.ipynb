# %%
# %%capture
# !pip install git+https://github.com/optuna/optuna.git #installa la libreria optuna

# %%
import pandas as pd
import numpy as np
import math as mh

import seaborn as sns
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn import linear_model

from keras import *
import tensorflow as tf
from keras.models import Sequential
from keras.layers.core import Dense, Dropout
from tensorflow.keras import regularizers
from keras.optimizers import Adam, RMSprop
from keras.backend import clear_session

import optuna
from optuna.samplers import RandomSampler
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
train = pd.read_csv("/content/drive/MyDrive/AML_project/train_manipulated_integrated.csv")

# %%
y_train = train['trip_duration'].values.reshape(-1, 1)

X_train = train.drop(columns = ['trip_duration'])

#divisione train test
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size = 0.30,
                                                  random_state = 1234)

# %%
#divisione train val
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = 0.15,
                                                  random_state = 1234)

# %%
print(X_train.shape)
print(X_val.shape)
print(X_test.shape)
# Out:
# (857057, 48)
# (151246, 48)
# (432130, 48)

# %%
#si separano le dummies dalle quantitative

X_train_to_stand = X_train[['passenger_count', 'distance',
                                            'maximum temperature', 'minimum temperature',
                                           'average temperature',
                                           'precipitation', 
                                           'snow fall',
                                           'snow depth', 'direction']]

X_train_not_stand = X_train.drop(columns = ['passenger_count', 'distance',
                                            'maximum temperature', 'minimum temperature',
                                           'average temperature',
                                           'precipitation', 
                                           'snow fall',
                                           'snow depth', 'direction']).values


X_val_to_stand = X_val[['passenger_count', 'distance',
                                            'maximum temperature', 'minimum temperature',
                                           'average temperature',
                                           'precipitation', 
                                           'snow fall',
                                           'snow depth', 'direction']]

X_val_not_stand = X_val.drop(columns = ['passenger_count', 'distance',
                                            'maximum temperature', 'minimum temperature',
                                           'average temperature',
                                           'precipitation', 
                                           'snow fall',
                                           'snow depth', 'direction']).values

X_test_to_stand = X_test[['passenger_count', 'distance',
                                            'maximum temperature', 'minimum temperature',
                                           'average temperature',
                                           'precipitation', 
                                           'snow fall',
                                           'snow depth', 'direction']]

X_test_not_stand = X_test.drop(columns = ['passenger_count', 'distance',
                                            'maximum temperature', 'minimum temperature',
                                           'average temperature',
                                           'precipitation', 
                                           'snow fall',
                                           'snow depth', 'direction']).values

# %%
#standardizzazione
scaler = StandardScaler()

X_train_stand = scaler.fit_transform(X_train_to_stand)
y_train_stand = scaler.fit(y_train).transform(y_train)

X_val_stand = scaler.fit(X_train_to_stand).transform(X_val_to_stand)
y_val_stand = scaler.fit(y_train).transform(y_val)

X_test_stand = scaler.fit(X_train_to_stand).transform(X_test_to_stand)
y_test_stand = scaler.fit(y_train).transform(y_test)

# %%
X_train = np.concatenate((X_train_stand, X_train_not_stand), axis = 1)
X_val = np.concatenate((X_val_stand, X_val_not_stand), axis = 1)
X_test = np.concatenate((X_test_stand, X_test_not_stand), axis = 1)

y_train = y_train_stand
y_val = y_val_stand
y_test = y_test_stand

# %%
print(X_train.shape)
print(X_val.shape)
print(X_test.shape)
# Out:
# (857057, 48)
# (151246, 48)
# (432130, 48)

# %%
print(y_train.shape)
print(y_val.shape)
print(y_test.shape)
# Out:
# (857057, 1)
# (151246, 1)
# (432130, 1)

# %%
### inizia l'ottimizzazione

es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=10, restore_best_weights=True)

def objective(trial): 
  clear_session()
  initializer = tf.keras.initializers.GlorotUniform(seed=1234) #inizializiamo i pesi
  #callback di early stopping
  es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', 
                                        patience=5, 
                                        restore_best_weights=True)
  #ottimizzatore
  opt = tf.keras.optimizers.SGD(learning_rate= 0.002, momentum=0.3, 
                              nesterov = False)

  callbacks_list = [optuna.integration.KerasPruningCallback(trial, 'val_loss'), 
                      es]

  #definizione dello spazio di ricerca
  n_hidden = trial.suggest_categorical("#hidden", [3, 4])

  if n_hidden == 3:
    units_1 = trial.suggest_int("dense1", 32, 256, step = 16)
    units_2 = trial.suggest_int("dense2", 32, 128, step = 16)
    units_3 = trial.suggest_int("dense3", 32, 128, step = 16)
    lambda_1 = trial.suggest_loguniform("lambda", 1e-4, 1e-1)
    activations = 'relu'

    model = Sequential()
    model.add(Dense(units_1, input_shape = (48,),
                  activation = activations, 
                  kernel_regularizer= regularizers.l1(lambda_1),
                  kernel_initializer=initializer))
    model.add(Dense(units_2,
                  activation = activations, 
                  kernel_regularizer= regularizers.l1(lambda_1),
                  kernel_initializer=initializer))
    model.add(Dense(units_3,
                  activation = activations, 
                  kernel_regularizer= regularizers.l1(lambda_1),
                  kernel_initializer=initializer))
    model.add(Dense(1,
                  activation = "linear", 
                  kernel_regularizer= regularizers.l1(lambda_1),
                  kernel_initializer=initializer))
  else:
    units_1 = trial.suggest_int("dense1", 32, 256, step = 16)
    units_2 = trial.suggest_int("dense2", 32, 128, step = 16)
    units_3 = trial.suggest_int("dense3", 32, 128, step = 16)
    units_4 = trial.suggest_int("dense4", 16, 64, step = 16)
    lambda_1 = trial.suggest_loguniform("lambda", 1e-4, 1e-1)
    activations = 'relu'

    model = Sequential()
    model.add(Dense(units_1, input_shape = (48,),
                  activation = activations, 
                  kernel_regularizer= regularizers.l1(lambda_1),
                  kernel_initializer=initializer))
    model.add(Dense(units_2,
                  activation = activations, 
                  kernel_regularizer= regularizers.l1(lambda_1),
                  kernel_initializer=initializer))
    model.add(Dense(units_3,
                  activation = activations, 
                  kernel_regularizer= regularizers.l1(lambda_1),
                  kernel_initializer=initializer))
    model.add(Dense(units_4,
                  activation = activations, 
                  kernel_regularizer= regularizers.l1(lambda_1),
                  kernel_initializer=initializer))
    model.add(Dense(1,
                  activation = "linear", 
                  kernel_regularizer= regularizers.l1(lambda_1),
                  kernel_initializer=initializer))
    
  model.compile(loss = "mse", optimizer=opt, metrics = [tf.keras.metrics.RootMeanSquaredError()])

  model.fit(X_train, y_train, epochs = 30, 
            batch_size = 128, validation_data=(X_val, y_val),
            shuffle = True,
            callbacks = callbacks_list,
            verbose=False)
  
  score = model.evaluate(X_val, y_val, verbose=0, batch_size = 128)

  return score[0]

# %%
sampler = RandomSampler(100) #random search

study = optuna.create_study(study_name = "l1_reg", direction="minimize", 
                            sampler = sampler, storage='sqlite:////content/drive/MyDrive/AML_project/sqlite/l1_reg.db', 
                            load_if_exists=True)
# Out:
# [I 2021-01-15 08:40:23,964] Using an existing study with name 'l1_reg' instead of creating a new one.

# %%
# %%time
# %%capture

study.optimize(objective, n_trials=50)
# Out:
# [I 2021-01-14 13:27:58,601] Trial 0 finished with value: 0.30836138129234314 and parameters: {'#hidden': 3, 'dense1': 160, 'dense2': 80, 'dense3': 32, 'lambda': 0.00027913514479844154}. Best is trial 0 with value: 0.30836138129234314.
# [I 2021-01-14 13:37:18,304] Trial 1 finished with value: 0.2905559241771698 and parameters: {'#hidden': 3, 'dense1': 64, 'dense2': 112, 'dense3': 64, 'lambda': 0.0004268971223779536}. Best is trial 1 with value: 0.2905559241771698.
# [I 2021-01-14 13:46:36,243] Trial 2 finished with value: 0.30746251344680786 and parameters: {'#hidden': 3, 'dense1': 48, 'dense2': 32, 'dense3': 32, 'lambda': 0.00015525411810181702}. Best is trial 1 with value: 0.2905559241771698.
# [I 2021-01-14 13:56:22,609] Trial 3 finished with value: 0.3258343040943146 and parameters: {'#hidden': 4, 'dense1': 224, 'dense2': 64, 'dense3': 32, 'dense4': 64, 'lambda': 0.0002114125046324832}. Best is trial 1 with value: 0.2905559241771698.
# [I 2021-01-14 14:00:28,307] Trial 4 finished with value: 0.513889491558075 and parameters: {'#hidden': 3, 'dense1': 64, 'dense2': 80, 'dense3': 96, 'lambda': 0.027230113230823506}. Best is trial 1 with value: 0.2905559241771698.
# [I 2021-01-14 14:00:49,190] Trial 5 pruned. Trial was pruned at epoch 0.
# [I 2021-01-14 14:05:24,443] Trial 6 pruned. Trial was pruned at epoch 13.
# [I 2021-01-14 14:05:45,763] Trial 7 pruned. Trial was pruned at epoch 0.
# [I 2021-01-14 14:06:06,686] Trial 8 pruned. Trial was pruned at epoch 0.
# [I 2021-01-14 14:11:26,716] Trial 9 pruned. Trial was pruned at epoch 16.
# [I 2021-01-14 14:11:46,898] Trial 10 pruned. Trial was pruned at epoch 0.
# [I 2021-01-14 14:12:06,577] Trial 11 pruned. Trial was pruned at epoch 0.
# [I 2021-01-14 14:18:39,081] Trial 12 pruned. Trial was pruned at epoch 20.
# [I 2021-01-14 14:19:00,089] Trial 13 pruned. Trial was pruned at epoch 0.
# [I 2021-01-14 14:24:14,010] Trial 14 pruned. Trial was pruned at epoch 15.
# [I 2021-01-14 14:24:33,843] Trial 15 pruned. Trial was pruned at epoch 0.
# [I 2021-01-14 14:24:55,212] Trial 16 pruned. Trial was pruned at epoch 0.
# [I 2021-01-14 14:25:15,281] Trial 17 pruned. Trial was pruned at epoch 0.
# [I 2021-01-14 14:25:36,537] Trial 18 pruned. Trial was pruned at epoch 0.
# [I 2021-01-14 14:29:13,474] Trial 19 pruned. Trial was pruned at epoch 10.
# [I 2021-01-14 14:29:32,976] Trial 20 pruned. Trial was pruned at epoch 0.
# [I 2021-01-14 14:29:54,086] Trial 21 pruned. Trial was pruned at epoch 0.
# [I 2021-01-14 14:30:13,907] Trial 22 pruned. Trial was pruned at epoch 0.
# [I 2021-01-14 14:30:34,579] Trial 23 pruned. Trial was pruned at epoch 0.
# [I 2021-01-14 14:34:56,195] Trial 24 pruned. Trial was pruned at epoch 12.
# [I 2021-01-14 14:35:16,170] Trial 25 pruned. Trial was pruned at epoch 0.
# [I 2021-01-14 14:35:36,978] Trial 26 pruned. Trial was pruned at epoch 0.
# [I 2021-01-14 14:35:57,077] Trial 27 pruned. Trial was pruned at epoch 0.
# [I 2021-01-14 14:40:04,867] Trial 28 pruned. Trial was pruned at epoch 12.
# [I 2021-01-14 14:40:24,510] Trial 29 pruned. Trial was pruned at epoch 0.
# [I 2021-01-14 14:40:44,899] Trial 30 pruned. Trial was pruned at epoch 0.
# [I 2021-01-14 14:41:05,907] Trial 31 pruned. Trial was pruned at epoch 0.
# [I 2021-01-14 14:46:07,271] Trial 32 pruned. Trial was pruned at epoch 15.
# [I 2021-01-14 14:49:14,354] Trial 33 pruned. Trial was pruned at epoch 9.
# [I 2021-01-14 14:53:37,602] Trial 34 pruned. Trial was pruned at epoch 13.
# [I 2021-01-14 14:53:58,718] Trial 35 pruned. Trial was pruned at epoch 0.
# [I 2021-01-14 14:54:19,840] Trial 36 pruned. Trial was pruned at epoch 0.
# [I 2021-01-14 14:59:19,536] Trial 37 pruned. Trial was pruned at epoch 14.
# [I 2021-01-14 14:59:39,711] Trial 38 pruned. Trial was pruned at epoch 0.
# [I 2021-01-14 15:00:00,795] Trial 39 pruned. Trial was pruned at epoch 0.
# [I 2021-01-14 15:00:21,897] Trial 40 pruned. Trial was pruned at epoch 0.
# [I 2021-01-14 15:00:43,228] Trial 41 pruned. Trial was pruned at epoch 0.
# [I 2021-01-14 15:01:02,988] Trial 42 pruned. Trial was pruned at epoch 0.
# [I 2021-01-14 15:01:24,156] Trial 43 pruned. Trial was pruned at epoch 0.
# [I 2021-01-14 15:05:49,600] Trial 44 pruned. Trial was pruned at epoch 13.
# [I 2021-01-14 15:06:10,850] Trial 45 pruned. Trial was pruned at epoch 0.
# [I 2021-01-14 15:10:49,624] Trial 46 pruned. Trial was pruned at epoch 13.
# [I 2021-01-14 15:15:35,478] Trial 47 pruned. Trial was pruned at epoch 14.
# [I 2021-01-14 15:15:56,620] Trial 48 pruned. Trial was pruned at epoch 0.
# [I 2021-01-14 15:16:17,652] Trial 49 pruned. Trial was pruned at epoch 0.
# CPU times: user 2h 30min 2s, sys: 23min 57s, total: 2h 53min 59s
# Wall time: 1h 57min 38s

# %%
print('Best trial number: ', study.best_trial.number)

print("Number of finished trials: {}".format(len(study.trials)))
trial = study.best_trial

print("  Value: {}".format(trial.value))
print('Best parameters: \n', study.best_trial.params)
# Out:
# Best trial number:  1
# Number of finished trials: 50
#   Value: 0.2905559241771698
# Best parameters:
#  {'#hidden': 3, 'dense1': 64, 'dense2': 112, 'dense3': 64, 'lambda': 0.0004268971223779536}

# %%
df_trials = study.trials_dataframe()

# %%
#si salvano le statistiche dei tentativi in un csv

df_trials.to_csv("/content/drive/MyDrive/AML_project/modelli/modelli salvati/opt_path/L1_reg.csv",
                 index = False)
